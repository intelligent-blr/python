# %% [markdown]
# ```
# 1. Напишите программу, которая запрашивает у пользователя строку и
# преобразует ее, удаляя все гласные буквы из строки. Используйте метод
# replace() для замены гласных букв на пустую строку. Выведите
# преобразованную строку на экран с помощью команды print.
#
# Пример вывода:
# Введите строку: Hello, world!
# Результат: Hll, wrld!
# ```

# %%
a = input('Введите строку: ')
glasnie = 'aeiouy'
for i in glasnie:
    a = a.replace(i, '')
print(a)
# Out:
# Введите строку: Hello, world!
# Hll, wrld!

# %% [markdown]
# ```
# 2. Напишите программу, которая запрашивает у пользователя строку и определяет,
# содержит ли она только уникальные символы. Если все символы в строке уникальны,
# выведите соответствующее сообщение на экран. В противном случае выведите
# сообщение о том, какие символы повторяются. Не используйте множества и подобные
# структуры данных, которые мы пока не изучали, для проверки уникальности символов.
#
# Пример вывода:
# Введите строку: Python
# Все символы в строке уникальны.
# Введите строку: Hello world
# Символы 'l' и 'o' повторяются.
# ```

# %%
a = input('Введите строку: ')
a = a.replace(' ', '')
unique = []
not_unique = []
for i in a:
    if i in unique:
        if i not in not_unique:
            not_unique.append(i)
    else:
        unique.append(i)
if len(not_unique) == 0:
    print('Все символы в строке уникальные')
else:
    print('Символы', ' и '.join(not_unique), 'повторяются')
# Out:
# Введите строку: Hello world
# Символы l и o повторяются

# %% [markdown]
# ```
# 3. Напишите программу, которая запрашивает у пользователя строку и выравнивает
# ее по центру с заданной шириной. Если строка не может быть выровнена по центру
# из-за нечетной ширины, она должна быть выровнена смещением вправо. Используйте
# методы center() и rjust() для выравнивания строки.
#
# Пример вывода:
# Введите строку: Python
# Введите ширину: 10
# Результат:
#   Python
# ```

# %%
a = input('Введите строку: ')
width = int(input('Введите ширину: '))
if width % 2 == 0:
    print(a.center(width))
else:
    print(a.rjust(width))
# Out:
# Введите строку: Python
# Введите ширину: 41
#                                    Python
