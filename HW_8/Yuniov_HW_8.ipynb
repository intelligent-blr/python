# %% [markdown]
# ```
# Напишите программу, которая запрашивает у пользователя целое число и определяет, является ли оно палиндромом.
# Число является палиндромом, если оно читается одинаково слева направо и справа налево.
# Выведите соответствующее сообщение на экран с помощью команды print.
# Используйте математические операции. Работу со строками использовать нельзя.
#
# Пример вывода:
# Введите целое число: 12321
# Число является палиндромом.
# ```

# %%
a = int(input('Введите целое число: '))
if a < 0:                                      # Проверяем, является ли число отрицательным
    print("Введите положительное число.")
else:
    temp = a
    revers_a = 0
    while temp > 0:
        last_number = temp % 10                # Убираем последнюю цифру
        revers_a = revers_a * 10 + last_number # Последняя цифра становится первой
        temp //= 10                            # Убираем последнюю цифру из введенного числа
    if a == revers_a:
        print('Число является палиндромом.')
    else:
        print('Число не является палиндромом.')
# Out:
# Введите целое число: 12321
# Число является палиндромом.

# %% [markdown]
# ```
# Напишите программу, которая запрашивает у пользователя целое число
# и проверяет является ли оно числом Армстронга. Число Армстронга - это число,
# которое равно сумме своих цифр, возведенных в степень, равную количеству цифр в числе.
# Выведите соответствующее сообщение на экран с помощью команды print.
#
# Пример вывода:
# Введите целое число: 153
# Число является числом Армстронга.
# ```

# %%
a = int(input("Введите целое число: "))
a_str = str(a)

num_a = 0
for digit in a_str:           # Считаем количество цифр в числе, можно было через len()
    num_a += 1

armstrong_sum = 0
i = 0
while i < num_a:
    armstrong_sum += int(a_str[i]) ** num_a
    i += 1
if armstrong_sum == a:
    print('Число является числом Армстронга.')
else:
    print('Число не является числом Армстронга.')
# Out:
# Введите целое число: 153
# Число является числом Армстронга.
