# %% [markdown]
# ```
# 1. Напишите программу, которая принимает список чисел от пользователя и
# передает его в функцию modify_list, которая изменяет элементы списка. Функция
# должна умножить нечетные числа на 2, а четные числа разделить на 2. Выведите
# измененный список на экран. Объясните, почему изменения происходят только
# внутри функции и как работают изменяемые и неизменяемые параметры.
#
# Пример вывода:
# Введите список чисел, разделенных пробелами: 1 2 3 4 5
# Измененный список чисел: [2, 1, 6, 2, 10]
# ```

# %%
def modify_list(user_list):
    new_list = []
    for number in user_list:
        if number % 2 == 0:
            new_list.append(number // 2)
        else:
            new_list.append(number * 2)
    return new_list

# %%
user_list = list(map(int, input('Введите список чисел, разделенных пробелами: ').split()))
print(f'Измененный список чисел: {modify_list(user_list)}')
# Out:
# Введите список чисел, разделенных пробелами: 1 2 3 4 5
# Измененный список чисел: [2, 1, 6, 2, 10]

# %% [markdown]
# ```
# Изменения внутри функции: список, который мы передаем в функцию, это ссылка (не
# сам список). Новый список, который я создал внутри функции - новая переменная и
# ссылается она на новый объект в памяти.
# Изменяемые можно изменить на месте, и изменения будут видны вне функции.
# Неизменяемые нельзя изменить на месте, и любые изменения создают новый объект.
# В нашем случае мы создаем новый список new_list, изменения не влияют на
# оригинальный список user_list.
# ```

# %% [markdown]
# ```
# 2. Напишите программу, которая принимает произвольное количество аргументов от
# пользователя и передает их в функцию calculate_sum, которая возвращает сумму
# всех аргументов. Используйте оператор * при передаче аргументов в функцию.
# Выведите результат на экран.
#
# Пример вывода:
# Введите числа, разделенные пробелами: 1 2 3 4 5
# Сумма чисел: 15
# ```

# %%
def calculate_sum(*args):
    return sum(args)

# %%
user_numbers = list(map(int, input('Введите числа, разделенные пробелами: ').split()))
result = calculate_sum(*user_numbers)
print(f'Сумма чисел: {result}')
# Out:
# Введите числа, разделенные пробелами: 1 2 3 4 5
# Сумма чисел: 15
