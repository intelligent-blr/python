# %% [markdown]
# ```
# 1. Напишите программу, которая запрашивает у пользователя три числа и выводит их в порядке возрастания, разделенные запятой. Используйте условные операторы и вложенные условия для решения задачи. Предполагается, что все три числа различны.
#
# Пример вывода:
# Введите первое число: 5
# Введите второе число: 2
# Введите третье число: 7
#
# Числа в порядке возрастания: 2, 5, 7

# %% [markdown]
# _Первый вариант:_

# %%
a = input('Введите первое число: ')
b = input('Введите второе число: ')
c = input('Введите третье число: ')
if a < b and a < c and b < c:
    print(f'Числа в порядке возрастания: {a}, {b}, {c}')
elif b < a and b < c and a < c :
    print(f'Числа в порядке возрастания: {b}, {a}, {c}')
elif c < a and c < b and a < b:
    print(f'Числа в порядке возрастания: {c}, {a}, {b}')
elif a < c and a < b and c < b :
    print(f'Числа в порядке возрастания: {a}, {c}, {b}')
elif c < b and c < a and b < a :
    print(f'Числа в порядке возрастания: {c}, {b}, {a}')
elif b < c and b < a and c < a:
    print(f'Числа в порядке возрастания: {b}, {c}, {a}')
# Out:
# Введите первое число:  7
# Введите второе число:  5
# Введите третье число:  2
# Числа в порядке возрастания: 2, 5, 7

# %% [markdown]
# _Второй вариант:_

# %%
a = input("Введите первое число: ")
b = input("Введите второе число: ")
c = input("Введите третье число: ")
if a < b:
    if a < c:
        if b < c:
            print(f'Числа в порядке возрастания: {a}, {b}, {c}')
        else:
            print(f'Числа в порядке возрастания: {a}, {c}, {b}')
    else:
        print(f'Числа в порядке возрастания: {c}, {a}, {b}')
else:
    if b < c:
        if c < a:
            if b < a:
                print(f'Числа в порядке возрастания: {b}, {c}, {a}')
        else:
            print(f'Числа в порядке возрастания: {b}, {a}, {c}')
    else:
        print(f'Числа в порядке возрастания: {c}, {b}, {a}')
# Out:
# Введите первое число:  7
# Введите второе число:  5
# Введите третье число:  2
# Числа в порядке возрастания: 2, 5, 7

# %% [markdown]
# ```
# 2. Напишите программу, которая запрашивает у пользователя год и проверяет, является ли он високосным. Год является високосным, если он делится на 4 без остатка, но не делится на 100 без остатка, за исключением годов, которые делятся на 400 без остатка. Выведите соответствующее сообщение на экран с помощью команды print.
#
# Пример вывода:
# Введите год: 2024
# Год является високосным.

# %%
a = int(input('Введите год: '))
if (a % 4 == 0 and a % 100 != 0) or (a % 400 == 0):
    print(f'Год является высокосным')
else:
    print(f'Год не является высокосным')
# Out:
# Введите год:  2024
# Год является высокосным

# %%
# дополнительные методы упрощения кода от Яна по обоим упражнениям
# 1) Позволяет избежать использования множества проверок. Не то что мы отрабатываем,но читаемость лучше. 
a = int(input("Введите первое число: "))
b = int(input("Введите второе число: "))
c = int(input("Введите третье число: "))

# Сортируем числа
sorted_numbers = sorted([a, b, c])
# Выводим результат
print("Числа в порядке возрастания:", ", ".join(map(str, sorted_numbers)))

# 2) Убираем двойной else
a = int(input("Введите год: "))
# Проверяем, является ли год високосным
if (a % 4 == 0 and a % 100 != 0) or (a % 400 == 0):
    print("Год является високосным.")
else:
    print("Год НЕ является високосным.")
